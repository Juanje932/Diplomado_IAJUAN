# %% [markdown]
# # Analisis exploratorio de datos tabulados

# %%
import pandas as pd

# %%
#Lectura de los datos

df = pd.read_csv('Human_Resources.csv')
df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
type(df) #que tipo de data es
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(2)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0              1             1.0                        2  Female          94
# 1              1             2.0                        3    Male          61
#
#    JobInvolvement  JobLevel             JobRole  JobSatisfaction  \
# 0               3         2     Sales Executive                4
# 1               2         2  Research Scientist                2
#
#   MaritalStatus  MonthlyRate  NumCompaniesWorked Over18 OverTime  \
# ...

# %%
df.tail(2)
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction Gender  \
# 1468              1          2065.0                        4   Male
# 1469              1          2068.0                        2   Male
#
#       HourlyRate  JobInvolvement  JobLevel                JobRole  \
# 1468          63               2         2        Sales Executive
# 1469          82               4         2  Laboratory Technician
#
#       JobSatisfaction MaritalStatus  MonthlyRate  NumCompaniesWorked Over18  \
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0              1             1.0                        2  Female          94
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   MonthlyIncome             1467 non-null   float64
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1469 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1469 non-null   object
#  9   EmployeeCount             1470 non-null   int64
#  10  EmployeeNumber            1469 non-null   float64
#  11  EnvironmentSatisfaction   1470 non-null   int64
#  12  Gender                    1469 non-null   object
# ...

# %%
df['Over18'].unique()
# Out:
# array(['Y'], dtype=object)

# %%
df.nunique()
# Out:
# Age                           43
# MonthlyIncome               1346
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1469
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyRate                 1425
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
#df.columns.to_list() #me genera una lista de los nombres de las columnas en la tabla
for name in df.columns.to_list():
    print(f'La columna:{name} contiene los elementos{df[name].unique()}')
# Out:
# La columna:Age contiene los elementos[41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# La columna:MonthlyIncome contiene los elementos[5993.   nan 2090. ... 9991. 5390. 4404.]
# La columna:Attrition contiene los elementos['Yes' 'No']
# La columna:BusinessTravel contiene los elementos['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# La columna:DailyRate contiene los elementos[1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
# ...

# %%
#eliminar columnas que no brindan informacion
valores_unicos_n = df.nunique()

columnas_sn_info = valores_unicos_n[valores_unicos_n==1].index.tolist()
columnas_sn_info
# Out:
# ['EmployeeCount', 'Over18', 'StandardHours']

# %%
df_clean = df.drop(columnas_sn_info, axis=1)

# %%
#df.drop(columnas_sn_info,axis=1,inplace=T) elimina del data frame original

# %%
df.head(3)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0              1             1.0                        2  Female          94
# 1              1             2.0                        3    Male          61
# 2              1             4.0                        4    Male          92
#
#    JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# ...

# %%
df_clean.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1470.000000    1467.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810    6505.155419   802.485714          9.192517     2.912925
# std       9.135373    4711.297846   403.509100          8.106864     1.024165
# min      18.000000    1009.000000   102.000000          1.000000     1.000000
# 25%      30.000000    2911.000000   465.000000          2.000000     2.000000
# 50%      36.000000    4908.000000   802.000000          7.000000     3.000000
# 75%      43.000000    8378.000000  1157.000000         14.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1469.000000              1470.000000  1470.000000     1470.000000
# mean      1025.556161                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ## division de un dataset

# %%
siguen_trabajando = df_clean[df_clean['Attrition'] == 'No'] # es un ejemplo de selecion de datos
renunciaron = df_clean[df_clean['Attrition'] == 'Yes']

# %%
renunciaron.describe()
# Out:
#               Age  MonthlyIncome    DailyRate  DistanceFromHome   Education  \
# count  237.000000     236.000000   237.000000        237.000000  237.000000
# mean    33.607595    4771.588983   750.362869         10.632911    2.839662
# std      9.689350    3640.097444   401.899519          8.452525    1.008244
# min     18.000000    1009.000000   103.000000          1.000000    1.000000
# 25%     28.000000    2371.500000   408.000000          3.000000    2.000000
# 50%     32.000000    3187.000000   699.000000          9.000000    3.000000
# 75%     39.000000    5850.000000  1092.000000         17.000000    4.000000
# max     58.000000   19859.000000  1496.000000         29.000000    5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count      237.000000               237.000000  237.000000      237.000000
# mean      1010.345992                 2.464135   65.573840        2.518987
# ...

# %%
siguen_trabajando.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1233.000000    1231.000000  1233.000000       1233.000000  1233.000000
# mean     37.561233    6837.504468   812.504461          8.915653     2.927007
# std       8.888360    4820.415800   403.208379          8.012633     1.027002
# min      18.000000    1051.000000   102.000000          1.000000     1.000000
# 25%      31.000000    3211.500000   477.000000          2.000000     2.000000
# 50%      36.000000    5206.000000   817.000000          7.000000     3.000000
# 75%      43.000000    8835.500000  1176.000000         13.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1232.000000              1233.000000  1233.000000     1233.000000
# mean      1028.482143                 2.771290    65.952149        2.770479
# ...

# %%
personas_sueldo_bien = siguen_trabajando[(siguen_trabajando['MonthlyIncome'] > 10000) & (siguen_trabajando['DistanceFromHome'] > 8) & (siguen_trabajando['EnvironmentSatisfaction']==4)]

# %%
personas_sueldo_bien.head()
# Out:
#      Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 98    58        13872.0        No      Travel_Rarely        682
# 112   54        17328.0        No         Non-Travel        142
# 147   41        17181.0        No  Travel_Frequently        857
# 235   43        16064.0        No      Travel_Rarely       1034
# 367   50        10496.0        No      Travel_Rarely       1046
#
#                  Department  DistanceFromHome  Education    EducationField  \
# 98                    Sales                10          4           Medical
# 112         Human Resources                26          3   Human Resources
# 147  Research & Development                10          3     Life Sciences
# 235                   Sales                16          3         Marketing
# 367  Research & Development                10          3  Technical Degree
#
#      EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# ...

# %%
personas_sueldo_bien['JobRole'].unique()
# Out:
# array(['Sales Executive', 'Manager', 'Healthcare Representative',
#        'Research Director', 'Manufacturing Director'], dtype=object)

# %%
personas_sueldo_bien[personas_sueldo_bien['JobRole']== 'Manager'].describe()
# Out:
#              Age  MonthlyIncome    DailyRate  DistanceFromHome  Education  \
# count  11.000000      11.000000    11.000000         11.000000  11.000000
# mean   45.545455   18115.000000   662.545455         16.000000   2.909091
# std     7.104416    1290.906891   446.154987          6.855655   0.539360
# min    33.000000   16064.000000   105.000000          9.000000   2.000000
# 25%    41.500000   17254.500000   189.500000          9.500000   3.000000
# 50%    45.000000   17650.000000   722.000000         16.000000   3.000000
# 75%    49.500000   19522.000000  1046.500000         21.500000   3.000000
# max    58.000000   19847.000000  1234.000000         26.000000   4.000000
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count       11.000000                     11.0   11.000000       11.000000
# mean      1188.454545                      4.0   74.545455        2.909091
# std        706.424711                      0.0   22.927554        0.539360
# ...

# %% [markdown]
# Se pudo notar que que los empleados que mas renuncian eras mas jovenes

# %% [markdown]
# ## Extraer numeros de una columna

# %%
import pandas as pd
import re
data = {'datos mezclados': ['4526 jdjdj', '2343 dfe','2321 jsjs','2311 sjsjs']}
df = pd.DataFrame(data)

# %%
data_num = '4526 jdjdj'
numero = re.search(r'\d+',data_num)
int(numero.group())
# Out:
# 4526

# %%
def extrac_numbers(s):
        numero = re.search(r'\d+',s)
        return int(numero.group())if numero else np.nan

# %%
df['datos mezclados'] = df['datos mezclados'].apply(extrac_numbers)

# %%
df
# Out:
#    datos mezclados
# 0             4526
# 1             2343
# 2             2321
# 3             2311

# %% [markdown]
# # Tratamiento de datos faltantes

# %%
#sirve para contar cuantos valores nulos tenemos por cada variable
valores_nulos = df_clean.isnull().sum()
valores_nulos
# Out:
# Age                         0
# MonthlyIncome               3
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeNumber              1
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyRate                 2
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           1
# PerformanceRating           1
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# ...

# %%
porcetaje = (valores_nulos / len(df_clean))*100
porcetaje
# Out:
# Age                         0.000000
# MonthlyIncome               0.204082
# Attrition                   0.000000
# BusinessTravel              0.000000
# DailyRate                   0.000000
# Department                  0.068027
# DistanceFromHome            0.000000
# Education                   0.000000
# EducationField              0.068027
# EmployeeNumber              0.068027
# EnvironmentSatisfaction     0.000000
# Gender                      0.068027
# HourlyRate                  0.000000
# JobInvolvement              0.000000
# JobLevel                    0.000000
# JobRole                     0.068027
# JobSatisfaction             0.000000
# MaritalStatus               0.068027
# MonthlyRate                 0.136054
# NumCompaniesWorked          0.000000
# OverTime                    0.000000
# PercentSalaryHike           0.068027
# PerformanceRating           0.068027
# RelationshipSatisfaction    0.000000
# StockOptionLevel            0.000000
# ...

# %%
#df_clean_sn_na = df_clean.dropna(axis=0)
#df_clean_sn_na = df_clean.dropna(subset=['ModuleNotFoundError','Department'])
#df_clean_sn_na = df_clean.dropna(axis=0)
#df_clean_sn_na = df_clean.fillna(0)
#df_clean['MonthlyIncome'] = df_clean['MonthlyIncome'].fillna(df_clean['MonthlyIncome'].median())

# %%
df_clean_sn_na.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[270], line 1
# ----> 1 df_clean_sn_na.isnull().sum()
#
# NameError: name 'df_clean_sn_na' is not defined

# %%
len(df_clean_sn_na)
# Out:
# 1470

# %%
#!pip install -U scikit-learn

# %%
from sklearn.impute import SimpleImputer
impute_numeric = SimpleImputer(strategy='mean')
numeric_columns = df_clean.select_dtypes(include=['number']).columns
numeric_columns
# Out:
# Index(['Age', 'MonthlyIncome', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyRate',
#        'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df_clean[numeric_columns] = impute_numeric.fit_transform(df_clean[numeric_columns])

# %%
from sklearn.impute import KNNImputer
impute_numeric = KNNImputer()
numeric_columns = df_clean.select_dtypes(include=['number']).columns
numeric_columns
# Out:
# Index(['Age', 'MonthlyIncome', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyRate',
#        'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#impute_categorico = SimpleImputer(strategy='most_frecuent')
#categorical_columns = df_clean.select_dtypes(include='object').columns
#df_clean[categorical_columns] = impute_categorico.fit_transform(df_clean[categorical_columns])

# %% [markdown]
# # Tratar con datos nominales y ordinales

# %%
for name in df_clean.columns.to_list():
    print(f'{name} : {df_clean[name].unique()}')
    print('\n')
# Out:
# Age : [41. 49. 37. 33. 27. 32. 59. 30. 38. 36. 35. 29. 31. 34. 28. 22. 53. 24.
#  21. 42. 44. 46. 39. 43. 50. 26. 48. 55. 45. 56. 23. 51. 40. 54. 58. 20.
#  25. 19. 57. 52. 47. 18. 60.]
#
#
# MonthlyIncome : [5993. 4908. 2090. ... 9991. 5390. 4404.]
#
#
# Attrition : [1 0]
#
#
# DailyRate : [1102.  279. 1373. 1392.  591. 1005. 1324. 1358.  216. 1299.  809.  153.
#   670. 1346.  103. 1389.  334. 1123. 1219.  371.  673. 1218.  419.  391.
#   699. 1282. 1125.  691.  477.  705.  924. 1459.  125.  895.  813. 1273.
#   869.  890.  852. 1141.  464. 1240. 1357.  994.  721. 1360. 1065.  408.
#  1211. 1229.  626. 1434. 1488. 1097. 1443.  515.  853. 1142.  655. 1115.
#   427.  653.  989. 1435. 1223.  836. 1195. 1339.  664.  318. 1225. 1328.
#  1082.  548.  132.  746.  776.  193.  397.  945. 1214.  111.  573. 1153.
#  1400.  541.  432.  288.  669.  530.  632. 1334.  638. 1093. 1217. 1353.
#   120.  682.  489.  807.  827.  871.  665. 1040. 1420.  240. 1280.  534.
# ...

# %%
# Tratas con variables ordinales
Attrition_labels = {'Yes':1, 'No':0}

df_clean['Attrition'] = df_clean['Attrition'].map(Attrition_labels)

# %%
df_clean
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
# Variables nominales
df_clean = pd.get_dummies(df_clean, columns=['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','OverTime'])

# %%
df_clean
# Out:
#        Age  MonthlyIncome  Attrition  DailyRate  DistanceFromHome  Education  \
# 0     41.0         5993.0          1     1102.0               1.0        2.0
# 1     49.0         4908.0          0      279.0               8.0        1.0
# 2     37.0         2090.0          1     1373.0               2.0        2.0
# 3     33.0         2909.0          0     1392.0               3.0        4.0
# 4     27.0         3468.0          0      591.0               2.0        1.0
# ...    ...            ...        ...        ...               ...        ...
# 1465  36.0         2571.0          0      884.0              23.0        2.0
# 1466  39.0         9991.0          0      613.0               6.0        1.0
# 1467  27.0         6142.0          0      155.0               4.0        3.0
# 1468  49.0         5390.0          0     1023.0               2.0        3.0
# 1469  34.0         4404.0          0      628.0               8.0        3.0
#
# ...

# %%
df_clean.describe()
# Out:
#                Age  MonthlyIncome    Attrition    DailyRate  DistanceFromHome  \
# count  1470.000000    1470.000000  1470.000000  1470.000000       1470.000000
# mean     36.923810    6501.895918     0.161224   802.485714          9.192517
# std       9.135373    4707.036942     0.367863   403.509100          8.106864
# min      18.000000    1009.000000     0.000000   102.000000          1.000000
# 25%      30.000000    2914.750000     0.000000   465.000000          2.000000
# 50%      36.000000    4908.000000     0.000000   802.000000          7.000000
# 75%      43.000000    8368.500000     0.000000  1157.000000         14.000000
# max      60.000000   19999.000000     1.000000  1499.000000         29.000000
#
#          Education  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count  1470.000000     1470.000000              1470.000000  1470.000000
# mean      2.912925     1025.556161                 2.721769    65.891156
# ...

# %% [markdown]
# ## Para pasar un documentos al excel

# %%
df_clean.to_csv('Preproced.csv',index=False)

# %% [markdown]
# ## Deteccion de valores atipicos

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
Q1 = df_clean['Age'].quantile(0.25)
Q3 = df_clean['Age'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5* IQR
limite_inferior
limite_superior = Q3 + 1.5* IQR
limite_superior
# Out:
# 62.5

# %%
#grafio de cajas y bigotes
df_clean.boxplot(column='Age')
# Out:
# <Axes: >

# %% [markdown]
# ## simulacion de datos por medio de los cuartiles

# %%
#este codigo es para generar datos atipoicos y ponerlos a prueba
df_test = df_clean.copy()

indices = np.random.choice(df_test.index,2,replace=False)

df_test.loc[indices[0],'Age']+= 3 * IQR
df_test.loc[indices[1],'Age']+= 3 * IQR

# %%
df_test.boxplot(column='Age')
# Out:
# <Axes: >

# %%
Q1 = df_test['Age'].quantile(0.25)
Q3 = df_test['Age'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5* IQR
limite_inferior
limite_superior = Q3 + 1.5* IQR
limite_superior
# Out:
# 62.5

# %%
df_test.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1470.000000    1467.000000  1470.000000       1470.000000  1470.000000
# mean     36.976871    6505.155419   802.485714          9.192517     2.912925
# std       9.236814    4711.297846   403.509100          8.106864     1.024165
# min      18.000000    1009.000000   102.000000          1.000000     1.000000
# 25%      30.000000    2911.000000   465.000000          2.000000     2.000000
# 50%      36.000000    4908.000000   802.000000          7.000000     3.000000
# 75%      43.000000    8378.000000  1157.000000         14.000000     4.000000
# max      75.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1469.000000              1470.000000  1470.000000     1470.000000
# mean      1025.556161                 2.721769    65.891156        2.729932
# ...

# %%
Q1 = df_clean['Age'].quantile(0.25)
Q3 = df_clean['Age'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5* IQR
limite_inferior
limite_superior = Q3 + 1.5* IQR
limite_superior
# Out:
# 62.5

# %%
plt.hist(df_clean['Age'], bins=30)
plt.show

# %%
sns.displot(x=df_clean['Age'])

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# ## Tomar 3 variables y determinar si existen datos atipicos

# %% [markdown]
# ### Variable 1 se detarmina que no hay datos atipicos por medio de la grafica de cajas y bigotes y el limite

# %%
df_clean.boxplot(column='DistanceFromHome')
Q1 = df_clean['DistanceFromHome'].quantile(0.25)
Q3 = df_clean['DistanceFromHome'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5* IQR
limite_inferior
limite_superior = Q3 + 1.5* IQR
print(limite_superior)
print(limite_inferior)
# Out:
# 32.0
# -16.0

# %% [markdown]
# ### SEgunda variable se notan datos atipicos despues de 16578

# %%
df_clean.boxplot(column='MonthlyIncome')
Q1 = df_clean['MonthlyIncome'].quantile(0.25)
Q3 = df_clean['MonthlyIncome'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5* IQR
limite_inferior
limite_superior = Q3 + 1.5* IQR
print(limite_superior)
print(limite_inferior)
# Out:
# 16578.5
# -5289.5

# %% [markdown]
# ### Se observa un dato atipico despues del 3

# %%
df_clean.boxplot(column='PerformanceRating')
Q1 = df_clean['PerformanceRating'].quantile(0.25)
Q3 = df_clean['PerformanceRating'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5* IQR
limite_inferior
limite_superior = Q3 + 1.5* IQR
print(limite_superior)
print(limite_inferior)
# Out:
# 3.0
# 3.0

# %%
df_clean.hist(bins=30,figsize=(30,30))
plt.show()

# %% [markdown]
# ## Metodo de Itrees bosques de aislamiento

# %% [markdown]
# ### algoritmo para sacar outlayes o datos atipicos se compara las variables y nos dice si es o no atipico

# %%
forest = IsolationForest(contamination='auto').fit(df_clean[["Age"]])

# %%
forest.predict(df_clean[['Age']])
# Out:
# array([-1, -1,  1, ...,  1, -1,  1])

# %%
forest.predict([[80]])
# Out:
# c:\Users\pickingp1\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# array([-1])

# %% [markdown]
# # Selecionar columnas para realizar modelo ya que no son es practico realizarlo utilizar todas las variables

# %%
import seaborn as sns
import pandas as pn

correlaciones1 = df_clean.corr()

f,ax = plt.subplots(figsize = (50,50))
sns.heatmap(correlaciones1,annot=True)
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[273], line 4
#       1 import seaborn as sns
#       2 import pandas as pn
# ----> 4 correlaciones1 = df_clean.corr()
#       6 f,ax = plt.subplots(figsize = (50,50))
#       7 sns.heatmap(correlaciones1,annot=True)
#
# File c:\Users\pickingp1\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\pickingp1\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# ...

# %%
sns.pairplot(df_clean,hue='Education', vars=['MonthlyIncome','YearsAtCompany'])
# Out:
# c:\Users\pickingp1\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\pickingp1\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### correlacion de las variables del grafico el siguiente codigo es para calcular la correlacion tambien de cualquier variable

# %%
new_data_ = df_clean[['MonthlyIncome','YearsAtCompany']].corr()

# %%
new_data_
# Out:
#                 MonthlyIncome  YearsAtCompany
# MonthlyIncome        1.000000        0.514168
# YearsAtCompany       0.514168        1.000000
